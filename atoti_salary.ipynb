# %%
import atoti as tt
# Out:
# Welcome to atoti 0.6.5!
#
# By using this community edition, you agree with the license available at https://docs.atoti.io/latest/eula.html.
# Browse the official documentation at https://docs.atoti.io.
# Join the community at https://www.atoti.io/register.
#
# atoti collects telemetry data, which is used to help understand how to improve the product.
# If you don't wish to send usage data, set the ATOTI_DISABLE_TELEMETRY environment variable to True.
#
# You can hide this message by setting the ATOTI_HIDE_EULA_MESSAGE environment variable to True.

# %%
session = tt.Session()

# %%
df = session.read_csv("data_cleaned_2021.csv")
df.head()
# Out:
#    index                                          Job Title  \
# 0    640                                      Data Engineer
# 1    642                            Scientist, Bacteriology
# 2    643                                     Data Scientist
# 3    644  Associate Director, Platform and DevOps- Data ...
# 4    645         Senior Research Scientist-Machine Learning
#
#                 Salary Estimate  \
# 0    $43K-$86K (Glassdoor est.)
# 1   $74K-$149K (Glassdoor est.)
# 2   $71K-$124K (Glassdoor est.)
# 3  $113K-$196K (Glassdoor est.)
# 4   $81K-$167K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Overview:\n\nGuidepoint Data identifies, gathe...     3.2
# 1  Scientist, Bacteriology\nLocation\n\n\nCerus U...     2.1
# 2  Overview\n\n\nDo you love numbers and finding ...     4.0
# 3  Job Description\n\n\nAre you looking for a pat...     3.7
# 4  What We Do:\n\nAt the SEI Emerging Technology ...     2.6
#
# ...

# %%
cube = session.create_cube(df)

# %%
# dir(cube) - aggregates_cache, create_date_hierarchy, create_parameter_hierarchy_from_column, create_parameter_hierarchy_from_members,
 # create_parameter_simulation, explain_query, hierarchies, levels, measures, name, query, schema, shared_context
cube
# Out:
# Cube(_name='Data_cleaned_2021', _hierarchies=Hierarchies(_create_hierarchy_from_arguments=<bound method Cube._create_hierarchy_from_arguments of ...>, _cube_name='Data_cleaned_2021'), _measures=Measures())

# %%
session.visualize()
# Out:
# Open the notebook in JupyterLab with the atoti extension enabled to build this widget.
